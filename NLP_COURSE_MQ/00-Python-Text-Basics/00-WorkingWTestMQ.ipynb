# %%
person= "Jose"

# %%
print("my name is {}".format(person))
# Out:
# my name is Jose

# %%
print(f"my name is {person}")
# Out:
# my name is Jose

# %%
print("my name is {person}")
# Out:
# my name is {person}

# %%
 d= {'a':1234, 'b':456}

# %%
print(f'my number is {d["a"]} and {d["b"]}')
# Out:
# my number is 1234 and 456

# %%
mylist = [3,2,1,0]

# %%
print(f'my number is {mylist[0]}')
# Out:
# my number is 3

# %%
library = [('Author', 'Topic', 'Pages'), ('Twain', 'Rafting', 601), ('Feynman', 'Physics', 95), ('Hamilton', 'Mythology', 144)]

# %%
library
# Out:
# [('Author', 'Topic', 'Pages'),
#  ('Twain', 'Rafting', 601),
#  ('Feynman', 'Physics', 95),
#  ('Hamilton', 'Mythology', 144)]

# %%
for book in library:
    print(f"Author: {book[0]}, Topic: {book[1]}, Pages: {book[2]}")
# Out:
# Author: Author, Topic: Topic, Pages: Pages
# Author: Twain, Topic: Rafting, Pages: 601
# Author: Feynman, Topic: Physics, Pages: 95
# Author: Hamilton, Topic: Mythology, Pages: 144

# %%
for author, topic, pages in library:
    print(f"{author:{10}} {topic:{30}} {pages:.>{10}}")
# Out:
# Author     Topic                          .....Pages
# Twain      Rafting                        .......601
# Feynman    Physics                        ........95
# Hamilton   Mythology                      .......144

# %%
from datetime import datetime
today = datetime(year=2019, month=2, day=28)

# %%
print(f'{today:%m/%d/%Y}')
print(f'{today:%B %d, %Y}')
# Out:
# 02/28/2019
# February 28, 2019

# %%
# %%writefile testMQ.txt
# Hello this is a quick test file.
# This is the second line of the file.
# Out:
# Writing testMQ.txt

# %%
myfile = open('testMQ.txt')

# %%
pwd
# Out:
# 'C:\\Users\\mbaqu\\Documents\\Datascience\\UPDATED_NLP_COURSE\\00-Python-Text-Basics'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readline()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
content = myfile.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-b40def5b9203> in <module>
# ----> 1 content = myfile.read()
#
# ValueError: I/O operation on closed file.

# %%
content
# Out:
# 'Hello this is a quick test file.\nThis is the second line of the file.\n'

# %%
print(content)
# Out:
# Hello this is a quick test file.
# This is the second line of the file.

# %%
myfile.close()

# %%
myfile.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-f51008fa62ae> in <module>
# ----> 1 myfile.read()
#
# ValueError: I/O operation on closed file.

# %%
for line in myfile:
    print(line)
# Out:
# Hello this is a quick test file.
#
# This is the second line of the file.

# %%
mylines = myfile.readlines()

# %%
mylines
# Out:
# ['Hello this is a quick test file.\n',
#  'This is the second line of the file.\n']

# %%
for l in mylines:
    print(l.split()[0])
# Out:
# Hello
# This

# %%
myfile= open('testMQ.txt','w+')

# %%
myfile.read()
# Out:
# ''

# %%
myfile.write("My brand new text")
# Out:
# 17

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'My brand new text'

# %%
myfilen.close()

# %%
myfile = open('woopsMQ.txt','a+')

# %%
myfile.write('My first line in a+ opening')
# Out:
# 27

# %%
myfile.close()

# %%
newfile = open('woopsMQ.txt', 'r')

# %%
newfile.read()
# Out:
# 'My first line in a+ opening'

# %%
newfile.close()

# %%
myfile = open('woopsMQ.txt', mode='a+')

# %%
myfile.write('This is an added line because I used the a+ mode')
# Out:
# 48

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'My first line in a+ openingThis is an added line because I used the a+ mode'

# %%
myfile.writelines('This is another new line on the next line')

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'My first line in a+ openingThis is an added line because I used the a+ modeThis is another new line on the next line'

# %%
myfile.write('\nYet another new line written in a+ mode')
# Out:
# 40

# %%
myfile.read()
# Out:
# 'My first line in a+ openingThis is an added line because I used the a+ modeThis is another new line on the next line\nYet another new line written in a+ mode'

# %%
myfile.seek(0)
# Out:
# 0

# %%
print(myfile.read())
# Out:
# My first line in a+ openingThis is an added line because I used the a+ modeThis is another new line on the next line
# Yet another new line written in a+ mode

# %%
myfile.close()

# %%
with open('woopsMQ.txt', 'r') as mynewfile:
    myvar = mynewfile.readlines()

# %%
myvar
# Out:
# ['My first line in a+ openingThis is an added line because I used the a+ modeThis is another new line on the next line\n',
#  'Yet another new line written in a+ mode']
