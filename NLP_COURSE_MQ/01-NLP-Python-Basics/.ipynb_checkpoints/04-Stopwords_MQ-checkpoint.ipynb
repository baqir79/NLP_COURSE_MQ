# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'anything', 'has', 'the', 'three', 'indeed', 'does', 'behind', 'while', 'and', 'itself', 'less', 'since', 'hundred', 'therein', 'whole', 'get', 'side', 'whence', 'rather', 'front', 'seemed', 'something', 'twenty', 'empty', 'had', 'nobody', 'latterly', 'on', 'seem', 'what', 'various', 'very', 'then', 'how', 'whether', 'being', 'we', 'why', 'himself', 'moreover', 'that', 'together', 'amongst', 'ever', 'throughout', 'whither', 'otherwise', 'although', 'forty', 'from', 'whereafter', 'wherein', 'never', 'during', 'regarding', 'per', 'all', 'unless', 'move', 'i', 'may', 'whatever', 'cannot', 'would', 'thru', 're', 'anywhere', 'everywhere', 'thus', 'keep', 'nowhere', 'last', 'becoming', 'along', 'because', 'put', 'me', 'hers', 'made', 'even', 'enough', 'now', 'over', 'yourself', 'besides', 'ca', 'ten', 'with', 'quite', 'where', 'across', 'us', 'again', 'whereby', 'both', 'have', 'via', 'if', 'latter', 'name', 'show', 'thereafter', 'except', 'was', 'alone', 'out', 'which', 'you', 'were', 'their', 'meanwhile', 'this', 'an', 'but', 'am', 'none', 'already', 'next', 'at', 'back', 'beside', 'such', 'those', 'off', 'full', 'onto', 'more', 'before', 'every', 'no', 'our', 'them', 'can', 'most', 'themselves', 'either', 'third', 'well', 'or', 'him', 'five', 'sixty', 'still', 'anyway', 'it', 'thereby', 'must', 'whoever', 'really', 'many', 'should', 'somewhere', 'thence', 'there', 'among', 'could', 'up', 'just', 'of', 'wherever', 'elsewhere', 'his', 'under', 'so', 'fifteen', 'make', 'for', 'however', 'using', 'nothing', 'further', 'afterwards', 'others', 'through', 'seeming', 'thereupon', 'eleven', 'a', 'almost', 'hereupon', 'in', 'often', 'therefore', 'whenever', 'do', 'once', 'beforehand', 'always', 'bottom', 'fifty', 'one', 'though', 'whereupon', 'yourselves', 'become', 'becomes', 'they', 'might', 'my', 'sometimes', 'first', 'perhaps', 'also', 'been', 'herein', 'ours', 'became', 'go', 'below', 'to', 'nine', 'serious', 'beyond', 'mine', 'several', 'anyone', 'are', 'against', 'is', 'own', 'whose', 'amount', 'he', 'six', 'part', 'call', 'eight', 'hereby', 'until', 'neither', 'namely', 'please', 'another', 'hereafter', 'two', 'ourselves', 'twelve', 'each', 'used', 'will', 'whom', 'yours', 'be', 'into', 'its', 'not', 'when', 'same', 'top', 'take', 'anyhow', 'mostly', 'without', 'only', 'your', 'noone', 'nevertheless', 'everyone', 'seems', 'few', 'else', 'sometime', 'who', 'other', 'whereas', 'former', 'around', 'give', 'least', 'between', 'somehow', 'any', 'formerly', 'after', 'four', 'as', 'her', 'herself', 'say', 'towards', 'within', 'too', 'yet', 'upon', 'here', 'she', 'these', 'everything', 'some', 'above', 'see', 'hence', 'about', 'toward', 'much', 'by', 'myself', 'done', 'due', 'nor', 'someone', 'did', 'doing', 'than', 'down'}

# %%
len(nlp.Defaults.stop_words)
# Out:
# 305

# %%
nlp.vocab['mystery'].is_stop
# Out:
# False

# %%
nlp.Defaults.stop_words.add('btw')

# %%
nlp.vocab['btw'].is_stop = True

# %%
len(nlp.Defaults.stop_words)
# Out:
# 306

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %%
nlp.Defaults.stop_words.remove('beyond')

# %%
nlp.vocab['beyond'].is_stop = False

# %%
nlp.vocab['beyond'].is_stop
# Out:
# False
